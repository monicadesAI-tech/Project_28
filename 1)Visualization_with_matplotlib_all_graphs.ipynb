# %% [markdown]
# # Visualization In Python through Matplotlib

# %% [markdown]
# ## What is Matplotlib?
#
# - Matplotlib is a 2D python plotting library.
#     - Visulize the data
#     - Identify Trends
#     - Identify outliers
#
#
# - Compatible with both NumPy and Pandas for plotting

# %%
# Visual representation of Pandas

import os
from IPython.display import Image
PATH = "C:\\Users\\Monica\\Desktop\\Projects\\Python Projects 1\\Visualization\\Project_4_Visualization_with_matplotlib_all_graphs\\"
Image(filename = PATH + "Matplotlib_Logo.png", width=600, height=300)

# %% [markdown]
# ## Overview
#
# - What is matplotlib and how/why it's used
#
# ### Using Numpy
# - Line plots using NumPy
# - Scatter Plots using NumPy
# - Bar plots & Subplots using Numpy
# - Histogram using NumPy
#
# ### Using Pandas
# - Line Plots using Pandas
# - Combo (Line & Bar) Plots using Pandas df
# - Scatterplot Using DFs
# - Scatterplots with Legends using Pandas

# %% [markdown]
# ## Importing / Installing packages

# %%
# Packages / libraries
import os #provides functions for interacting with the operating system
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Line Graphs using Matplotlib & Numpy

# %%
# Creating an array

a = np.array([1,2,3,4,5])
a

plt.plot(a)
plt.savefig('Line_Graph1.png', dpi=300)
plt.show()

# %%
# Creating 2 arrays
a = np.array([1,2,3,4,5])
b = np.array([2,2,2,2,2])

plt.plot(a,b)
plt.savefig('Line_Graph2.png', dpi=300)
plt.show()

# %%
##### Having more than 1 line - Adding Title, legends and x/y tickers

# creating the raw
a = np.array([1,2,3,4,5])
b = np.array([2,2,2,2,2])
c = np.array([3,2,4,6,5])

# increase size
plt.figure(figsize=(15,10))

plt.plot(a, color = 'green', linestyle = '-.', label="Rent FY20")
plt.plot(b, linewidth=5., label="AVG Rent")
plt.plot(c, color = 'red', linestyle = '--', label="Rent FY19")
plt.title("Rent per Month Summary", fontsize=20, fontweight="bold")
plt.legend(loc="upper left", fontsize=15)
plt.xticks(range(0,len(a)),('Jan','Feb','Mar','Apr','May'))
#plt.xticks([0,1,2,3,4])
plt.xlabel("Months")
plt.ylabel("Rent $")
plt.savefig('Line_Graph3.png', dpi=300)
plt.show()

# %% [markdown]
# ## 2. Scatter Plots using Matplotlib & Numpy

# %%
# Simple Example

# np.arange: from 0 to the number you specify
# np.random.randint: From -> To ,Number of numbers you need
# np.random.randn(): random numbers with normal distribution (mean 0 and variance 1)

a = np.arange(30)
b = np.random.randint(0,30,30)

plt.scatter(a,b)
plt.savefig('Scatter_Graph1.png', dpi=300)
plt.show()

# %%
# Example 2 - Scatter with size

s = np.random.randint(0,100,30)

b = a + np.random.randint(0,30,30)

plt.scatter(a,b, c="green", s=s)
plt.savefig('Scatter_Graph2.png', dpi=300)
plt.show()

# %% [markdown]
# ## 3. Bar Plots using Matplotlib & Numpy

# %%
# Example 1

# Creating the raw data
category = ['Account A','Account B','Account C']
revenue = np.array([300, 500, 700])


# Plotting it
plt.figure(figsize=(10,10))
plt.bar(range(0,3), revenue)
plt.xticks(range(0,3),category)
plt.savefig('Bar_Graph1.png', dpi=300)
plt.show()

# %%
# Example 2 - Subplots

# Creating the raw data
category = ['Account A','Account B','Account C']
revenue = np.array([300, 450, 700])

# Plotting it
plt.figure(figsize=(10,5))

# bar
plt.subplot(131)
plt.bar(range(0,3), revenue)
plt.xticks(range(0,3),category)


# line
plt.subplot(132)
plt.plot(range(0,3), revenue, c="red")
plt.xticks(range(0,3),category)


# scatter
plt.subplot(133)
plt.scatter(range(0,3), revenue, c="green")
plt.xticks(range(0,3),category)
plt.savefig('Bar_Line_Scatter_Graph.png', dpi=300)
plt.show()

# %% [markdown]
# ## 4. Histogram

# %%
#Example 1 

# creating the raw data
a = np.random.randn(10000) * 10 +100
a 

# plotting

plt.hist(a, 7)
plt.title("No of Houses per Square M")
plt.xlabel("Square M Bins")
plt.ylabel("No of houses")
plt.savefig('Histogram.png', dpi=300)
plt.show()

# %% [markdown]
# ## 5. Lineplots using Pandas' DFs

# %%
# This is to find out your current directory
# cwd = os.getcwd()
# cwd

# %%
# Loading the data

raw_data = pd.read_csv("C:\\Users\\Monica\\Desktop\\Projects\\Python Projects 1\\Visualization\\Project_4_Visualization_with_matplotlib_all_graphs\\Marketing Raw Data.csv")
# runs all the data
raw_data

print(raw_data.shape)

#runs the first 5 rows
raw_data.head()
# Out:
# (182, 6)
#          Date   Day_Name  Visitors  Revenue  Marketing Spend           Promo
# 0  09/11/2020     Monday       707     5211          651.375        No Promo
# 1  10/11/2020    Tuesday      1455    10386         1298.250   Promotion Red
# 2  11/11/2020  Wednesday      1520    12475         1559.375  Promotion Blue
# 3  12/11/2020   Thursday      1726    14414         1801.750        No Promo
# 4  13/11/2020     Friday      2134    20916         2614.500        No Promo

# %%
# Example 1 - Simple line graph

plt.plot(raw_data["Visitors"])
plt.savefig('Simple_Line_Graph1.png', dpi=300)
plt.show()

# %%
# Example 2 - Line graphs with xtickers

plt.plot(raw_data["Visitors"])
plt.xticks(range(0,len(raw_data["Visitors"])), raw_data["Date"], rotation = 90)
plt.savefig('Simple_Line_Graph2.png', dpi=300)
plt.show()

# %%
# Example 3 - Line graphs with xtickers and less data

a = raw_data.tail(10).reset_index()

plt.plot(a["Visitors"])
plt.xticks(range(0,len(a["Visitors"])), a["Date"], rotation = 90)
plt.savefig('Simple_Line_Graph3.png', dpi=300)
plt.show()

# %%
# Example 4 - 2+ data points on the graph

plt.figure(figsize=(15,10))
plt.plot(a["Visitors"], label="No. of Visistors", linewidth=5.)
plt.plot(a["Revenue"], linestyle = "-.")
plt.xticks(range(0,len(a["Visitors"])), a["Date"], rotation = 90)
plt.title("Visitors & Revenue by Day", fontsize = 20)
plt.legend(loc="upper right", fontsize=14)
plt.xlabel("Dates")
plt.savefig('Simple_Line_Graph4.png', dpi=300)
plt.show()

# %%
# Example 5 - Combo graphs

plt.figure(figsize=(15,10))
plt.bar(range(0,len(a["Visitors"])), a["Visitors"], label="No. of Visitors", linewidth=5., color = "green")
plt.plot(a["Revenue"], linestyle = "-.")
plt.xticks(range(0,len(a["Visitors"])), a["Date"], rotation = 90)
plt.title("Visitors & Revenue by Day", fontsize = 20)
plt.legend(loc="upper right", fontsize=14)
plt.xlabel("Dates")
plt.savefig('Simple_Line_Bar_Graph5.png', dpi=300)
plt.show()

# %%
# Example 6 - Combo stack bars


plt.figure(figsize=(15,10))
plt.bar(range(0,len(a["Revenue"])), a["Revenue"], label="Revenue", linewidth=5., color = "green")
plt.bar(range(0,len(a["Visitors"])), a["Marketing Spend"], label="Marketing Spend", linewidth=5., color = "red")

plt.plot(a["Visitors"], linestyle = "-.")

plt.xticks(range(0,len(a["Visitors"])), a["Date"], rotation = 90)
plt.title("Visitors & Revenue by Day", fontsize = 20)
plt.legend(loc="upper right", fontsize=14)
plt.xlabel("Dates")
plt.savefig('Simple_Line__Bar_Graph6.png', dpi=300)
plt.show()

# %%
# Example 7 - Combo 2+ bar graphs + Secondary Scale

weight = .30

a[["Revenue", "Marketing Spend"]].plot(kind="bar", color = ["green", "red"], figsize=(15,10))
a["Visitors"].plot(c="blue", linestyle = "-.", secondary_y=True)

plt.xticks(range(0,len(a["Visitors"])), a["Date"], rotation = 90)
plt.title("Visitors & Revenue by Day", fontsize = 20)
plt.legend(loc="upper left", fontsize=14)
plt.xlabel("Dates")
plt.xlim(-weight, len(a["Visitors"])-weight)
plt.savefig('Simple_Line_Double_Bar_Graph7.png', dpi=300)
plt.show()

# examples of Kind
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html

# %% [markdown]
# ## 6. Scatterplot Using DFs

# %%
# Example 1 - Simple Scatterplot

plt.figure(figsize=(15,10))
plt.scatter(raw_data["Revenue"], raw_data["Marketing Spend"], c="red", marker='+')
plt.title("Relationship between M. Spend & Revenue", fontsize = 20)
plt.legend(loc="upper left", fontsize=14)
plt.xlabel("Revenue")
plt.ylabel("Marketing Spend")
plt.savefig('Scatter_Graph3.png', dpi=300)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
raw_data.head()
# Out:
#          Date   Day_Name  Visitors  Revenue  Marketing Spend           Promo
# 0  09/11/2020     Monday       707     5211          651.375        No Promo
# 1  10/11/2020    Tuesday      1455    10386         1298.250   Promotion Red
# 2  11/11/2020  Wednesday      1520    12475         1559.375  Promotion Blue
# 3  12/11/2020   Thursday      1726    14414         1801.750        No Promo
# 4  13/11/2020     Friday      2134    20916         2614.500        No Promo

# %%
# Example 2 - Scatterplot with groups

groups = raw_data[["Promo","Revenue","Marketing Spend"]].groupby("Promo")
groups

fig, ax = plt.subplots(figsize=(15,10))

for promo, group in groups:
    ax.scatter(group['Revenue'], group['Marketing Spend'], marker = 'x', label=promo)

ax.legend()
plt.title("Relationship between M. Spend & Revenue by Promo", fontsize = 20)
plt.xlabel("Revenue")
plt.ylabel("Marketing Spend")
plt.savefig('Scatter_Graph4.png', dpi=300)
plt.show()

# %%
# Example 3 - Scatterplot with groups

groups = raw_data[["Day_Name","Revenue","Marketing Spend"]].groupby("Day_Name")
groups

fig, ax = plt.subplots(figsize=(15,10))

for promo, group in groups:
    ax.scatter(group['Revenue'], group['Marketing Spend'], marker = 'x', label=promo)

ax.legend()
plt.title("Relationship between M. Spend & Revenue by Day_Name", fontsize = 20)
plt.xlabel("Revenue")
plt.ylabel("Marketing Spend")
plt.savefig('Scatter_Graph5.png', dpi=300)
plt.show()
